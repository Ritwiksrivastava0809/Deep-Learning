# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %% [markdown]
# ## 2.2 Model
# <img align="Right" src="./images/C2_W2_mclass_lab_network.PNG"  style=" width:350px; padding: 10px 20px ; ">
# This lab will use a 2-layer network as shown.
# Unlike the binary classification networks, this network has four outputs, one for each class. Given an input example, the output with the highest value is the predicted class of the input.
#
# Below is an example of how to construct this network in Tensorflow. Notice the output layer uses a `linear` rather than a `softmax` activation. While it is possible to include the softmax in the output layer, it is more numerically stable if linear outputs are passed to the loss function during training. If the model is used to predict probabilities, the softmax can be applied at that point.

# %%
# make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")
# show how classes are represented
print(f"class representation {y_train[:10]}")
# show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %% [markdown]
# ## 2.2 Model
# <img align="Right" src="C:\c++\My codes\photos\C2_W2_mclass_lab_network.png"  style=" width:350px; padding: 10px 20px ; ">
# This lab will use a 2-layer network as shown.
# Unlike the binary classification networks, this network has four outputs, one for each class. Given an input example, the output with the highest value is the predicted class of the input.
#
# Below is an example of how to construct this network in Tensorflow. Notice the output layer uses a `linear` rather than a `softmax` activation. While it is possible to include the softmax in the output layer, it is more numerically stable if linear outputs are passed to the loss function during training. If the model is used to predict probabilities, the softmax can be applied at that point.

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results
model = Sequential(
    [
        Dense(2, activation = 'relu',   name = "L1"),
        Dense(4, activation = 'linear', name = "L2")
    ]
)

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X_train,y_train,
    epochs=200
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9543
# Epoch 2/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7356
# Epoch 3/200
# 4/4 [==============================] - 0s 0s/step - loss: 1.5585
# Epoch 4/200
# 4/4 [==============================] - 0s 0s/step - loss: 1.4149
# Epoch 5/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3045
# Epoch 6/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2087
# Epoch 7/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1353
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0699
# Epoch 9/200
# 4/4 [==============================] - 0s 0s/step - loss: 1.0193
# Epoch 10/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.9716
# Epoch 11/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.9347
# Epoch 12/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9059
# Epoch 13/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.8880
# Epoch 14/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8698
# Epoch 15/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8543
# Epoch 16/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8433
# Epoch 17/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8331
# Epoch 18/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8227
# Epoch 19/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8142
# Epoch 20/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.8057
# Epoch 21/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7983
# Epoch 22/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7904
# Epoch 23/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7830
# Epoch 24/200
# 4/4 [==============================] - 0s 502us/step - loss: 0.7770
# Epoch 25/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.7699
# Epoch 26/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.7637
# Epoch 27/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.7585
# Epoch 28/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7529
# Epoch 29/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7475
# Epoch 30/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.7429
# Epoch 31/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.7377
# Epoch 32/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.7326
# Epoch 33/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.7285
# Epoch 34/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.7239
# Epoch 35/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.7183
# Epoch 36/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7141
# Epoch 37/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7092
# Epoch 38/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7031
# Epoch 39/200
# 4/4 [==============================] - 0s 336us/step - loss: 0.6975
# Epoch 40/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6933
# Epoch 41/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6891
# Epoch 42/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6856
# Epoch 43/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6806
# Epoch 44/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6744
# Epoch 45/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.6701
# Epoch 46/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6695
# Epoch 47/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6659
# Epoch 48/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6625
# Epoch 49/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6569
# Epoch 50/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6535
# Epoch 51/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.6494
# Epoch 52/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.6491
# Epoch 53/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.6471
# Epoch 54/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6436
# Epoch 55/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.6378
# Epoch 56/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.6301
# Epoch 57/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6297
# Epoch 58/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6309
# Epoch 59/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6295
# Epoch 60/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6233
# Epoch 61/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6169
# Epoch 62/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6132
# Epoch 63/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6104
# Epoch 64/200
# 4/4 [==============================] - 0s 458us/step - loss: 0.6082
# Epoch 65/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.6092
# Epoch 66/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6080
# Epoch 67/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.6047
# Epoch 68/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6022
# Epoch 69/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5982
# Epoch 70/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5965
# Epoch 71/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5949
# Epoch 72/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5931
# Epoch 73/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5907
# Epoch 74/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5891
# Epoch 75/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5859
# Epoch 76/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5866
# Epoch 77/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5853
# Epoch 78/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5842
# Epoch 79/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5818
# Epoch 80/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5777
# Epoch 81/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5756
# Epoch 82/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5748
# Epoch 83/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5753
# Epoch 84/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5711
# Epoch 85/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5694
# Epoch 86/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5693
# Epoch 87/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5699
# Epoch 88/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5682
# Epoch 89/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5653
# Epoch 90/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5647
# Epoch 91/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5638
# Epoch 92/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5603
# Epoch 93/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5589
# Epoch 94/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5570
# Epoch 95/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5538
# Epoch 96/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5529
# Epoch 97/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5520
# Epoch 98/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5515
# Epoch 99/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5492
# Epoch 100/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5470
# Epoch 101/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5482
# Epoch 102/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5512
# Epoch 103/200
# 4/4 [==============================] - 0s 669us/step - loss: 0.5469
# Epoch 104/200
# 4/4 [==============================] - 0s 511us/step - loss: 0.5410
# Epoch 105/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5394
# Epoch 106/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5384
# Epoch 107/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5341
# Epoch 108/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5278
# Epoch 109/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5251
# Epoch 110/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5223
# Epoch 111/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5188
# Epoch 112/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5151
# Epoch 113/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5093
# Epoch 114/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5041
# Epoch 115/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.4976
# Epoch 116/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.4915
# Epoch 117/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.4833
# Epoch 118/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.4760
# Epoch 119/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.4682
# Epoch 120/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.4570
# Epoch 121/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.4447
# Epoch 122/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4336
# Epoch 123/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4210
# Epoch 124/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4096
# Epoch 125/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3983
# Epoch 126/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3871
# Epoch 127/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3760
# Epoch 128/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3654
# Epoch 129/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3529
# Epoch 130/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3407
# Epoch 131/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3302
# Epoch 132/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3189
# Epoch 133/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3100
# Epoch 134/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3001
# Epoch 135/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2914
# Epoch 136/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2816
# Epoch 137/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2721
# Epoch 138/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2649
# Epoch 139/200
# 4/4 [==============================] - 0s 711us/step - loss: 0.2561
# Epoch 140/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.2478
# Epoch 141/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2385
# Epoch 142/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2304
# Epoch 143/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2232
# Epoch 144/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.2148
# Epoch 145/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.2064
# Epoch 146/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1977
# Epoch 147/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1899
# Epoch 148/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1823
# Epoch 149/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1742
# Epoch 150/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1644
# Epoch 151/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1537
# Epoch 152/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1481
# Epoch 153/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1449
# Epoch 154/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1408
# Epoch 155/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1346
# Epoch 156/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1280
# Epoch 157/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1208
# Epoch 158/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1155
# Epoch 159/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1110
# Epoch 160/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1074
# Epoch 161/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1040
# Epoch 162/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1014
# Epoch 163/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0990
# Epoch 164/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0950
# Epoch 165/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0924
# Epoch 166/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0900
# Epoch 167/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0880
# Epoch 168/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0859
# Epoch 169/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0838
# Epoch 170/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0818
# Epoch 171/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0801
# Epoch 172/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0783
# Epoch 173/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0768
# Epoch 174/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0751
# Epoch 175/200
# 4/4 [==============================] - 0s 835us/step - loss: 0.0737
# Epoch 176/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0719
# Epoch 177/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0706
# Epoch 178/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0691
# Epoch 179/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0679
# Epoch 180/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0664
# Epoch 181/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0651
# Epoch 182/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0640
# Epoch 183/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0629
# Epoch 184/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0619
# Epoch 185/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0609
# Epoch 186/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0600
# Epoch 187/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0590
# Epoch 188/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0580
# Epoch 189/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0574
# Epoch 190/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0565
# Epoch 191/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0556
# Epoch 192/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0548
# Epoch 193/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0540
# Epoch 194/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0533
# Epoch 195/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0525
# Epoch 196/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0519
# Epoch 197/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0513
# Epoch 198/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0506
# Epoch 199/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0500
# Epoch 200/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0494

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 184/184 [==============================] - 0s 918us/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1")
W1,b1 = l1.get_weights()

# %%
# plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()
# create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1)

plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# ## Explanation
# #### Layer 1 <img align="Right" src="./images/C2_W2_mclass_layer1.png"  style=" width:600px; padding: 10px 20px ; ">
# These plots show the function of Units 0 and 1 in the first layer of the network. The inputs are ($x_0,x_1$) on the axis. The output of the unit is represented by the color of the background. This is indicated by the color bar on the right of each graph. Notice that since these units are using a ReLu, the outputs do not necessarily fall between 0 and 1 and in this case are greater than 20 at their peaks.
# The contour lines in this graph show the transition point between the output, $a^{[1]}_j$ being zero and non-zero. Recall the graph for a ReLu :<img align="right" src="./images/C2_W2_mclass_relu.png"  style=" width:200px; padding: 10px 20px ; "> The contour line in the graph is the inflection point in the ReLu.
#
# Unit 0 has separated classes 0 and 1 from classes 2 and 3. Points to the left of the line (classes 0 and 1) will output zero, while points to the right will output a value greater than zero.
# Unit 1 has separated classes 0 and 2 from classes 1 and 3. Points above the line (classes 0 and 2 ) will output a zero, while points below will output a value greater than zero. Let's see how this works out in the next layer!

# %% [markdown]
# #### Layer 2, the output layer  <img align="Right" src="./images/C2_W2_mclass_layer2.png"  style=" width:600px; padding: 10px 20px ; ">
#
# The dots in these graphs are the training examples translated by the first layer. One way to think of this is the first layer has created a new set of features for evaluation by the 2nd layer. The axes in these plots are the outputs of the previous layer $a^{[1]}_0$ and $a^{[1]}_1$. As predicted above, classes 0 and 1 (blue and green) have  $a^{[1]}_0 = 0$ while classes 0 and 2 (blue and orange) have $a^{[1]}_1 = 0$.
# Once again, the intensity of the background color indicates the highest values.
# Unit 0 will produce its maximum value for values near (0,0), where class 0 (blue) has been mapped.
# Unit 1 produces its highest values in the upper left corner selecting class 1 (green).
# Unit 2 targets the lower right corner where class 2 (orange) resides.
# Unit 3 produces its highest values in the upper right selecting our final class (purple).
#
# One other aspect that is not obvious from the graphs is that the values have been coordinated between the units. It is not sufficient for a unit to produce a maximum value for the class it is selecting for, it must also be the highest value of all the units for points in that class. This is done by the implied softmax function that is part of the loss function (`SparseCategoricalCrossEntropy`). Unlike other activation functions, the softmax works across all the outputs.
#
# You can successfully use neural networks without knowing the details of what each unit is up to. Hopefully, this example has provided some intuition about what is happening under the hood.
